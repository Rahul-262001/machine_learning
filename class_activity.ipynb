# %%
import pandas as pd
df=pd.read_csv('fruits.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Weight  40 non-null     int64
#  1   Size    40 non-null     float64
#  2   Class   40 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.1+ KB

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.pairplot(data=df)

# %%
sns.lineplot(data=df,y='Weight',x='Size')
# Out:
# <Axes: xlabel='Size', ylabel='Weight'>

# %%
sns.catplot(data=df,x='Weight',y='Size',kind='violin')

# %%
sns.catplot(data=df,x='Weight',y='Size',kind='swarm')

# %%
sns.catplot(data=df,x='Weight',y='Size',kind='box')

# %%
sns.relplot(
    data=df, x="Weight", y='Size', 
    kind="line",height=10, aspect=.9,
)

# %%
# !poweroff
